# %%
import os

# %cd /kaggle/working

if not os.path.exists("synth_ds_creation"):
    # !git clone https://github.com/11MindFlayer11/synth_ds_creation.git
else:
    # %cd synth_ds_creation
    # !git pull

# %cd /kaggle/working/synth_ds_creation/gaussian-pipeline
# Out:
# Current working directory: d:\Voccl3d

# %%
# !pip install -r requirements.txt

# %%
from pipeline.install import Installer

installer = Installer()

installer.install_everything()
